# %%
tabla_periodica = {
    "H": {"nombre": "Hidrógeno", "número atómico": 1, "masa atómica": 1.008, "grupo": 1, "periodo": 1},
    "He": {"nombre": "Helio", "número atómico": 2, "masa atómica": 4.0026, "grupo": 18, "periodo": 1},
    "Li": {"nombre": "Litio", "número atómico": 3, "masa atómica": 6.94, "grupo": 1, "periodo": 2},
    "Be": {"nombre": "Berilio", "número atómico": 4, "masa atómica": 9.0122, "grupo": 2, "periodo": 2},
    "B": {"nombre": "Boro", "número atómico": 5, "masa atómica": 10.81, "grupo": 13, "periodo": 2},
    "C": {"nombre": "Carbono", "número atómico": 6, "masa atómica": 12.011, "grupo": 14, "periodo": 2},
    "N": {"nombre": "Nitrógeno", "número atómico": 7, "masa atómica": 14.007, "grupo": 15, "periodo": 2},
    "O": {"nombre": "Oxígeno", "número atómico": 8, "masa atómica": 15.999, "grupo": 16, "periodo": 2},
    "F": {"nombre": "Flúor", "número atómico": 9, "masa atómica": 18.998, "grupo": 17, "periodo": 2},
    "Ne": {"nombre": "Neón", "número atómico": 10, "masa atómica": 20.18, "grupo": 18, "periodo": 2},
    "Na": {"nombre": "Sodio", "número atómico": 11, "masa atómica": 22.99, "grupo": 1, "periodo": 3},
    "Mg": {"nombre": "Magnesio", "número atómico": 12, "masa atómica": 24.305, "grupo": 2, "periodo": 3},
    "Al": {"nombre": "Aluminio", "número atómico": 13, "masa atómica": 26.982, "grupo": 13, "periodo": 3},
    "Si": {"nombre": "Silicio", "número atómico": 14, "masa atómica": 28.085, "grupo": 14, "periodo": 3},
    "P": {"nombre": "Fósforo", "número atómico": 15, "masa atómica": 30.974, "grupo": 15, "periodo": 3},
    "S": {"nombre": "Azufre", "número atómico": 16, "masa atómica": 32.06, "grupo": 16, "periodo": 3},
    "Cl": {"nombre": "Cloro", "número atómico": 17, "masa atómica": 35.45, "grupo": 17, "periodo": 3},
    "Ar": {"nombre": "Argón", "número atómico": 18, "masa atómica": 39.95, "grupo": 18, "periodo": 3},
    "K": {"nombre": "Potasio", "número atómico": 19, "masa atómica": 39.098, "grupo": 1, "periodo": 4},
    "Ca": {"nombre": "Calcio", "número atómico": 20, "masa atómica": 40.078, "grupo": 2, "periodo": 4},
    "Sc": {"nombre": "Escandio", "número atómico": 21, "masa atómica": 44.956, "grupo": 3, "periodo": 4},
    "Ti": {"nombre": "Titanio", "número atómico": 22, "masa atómica": 47.867, "grupo": 4, "periodo": 4},
    "V": {"nombre": "Vanadio", "número atómico": 23, "masa atómica": 50.942, "grupo": 5, "periodo": 4},
    "Cr": {"nombre": "Cromo", "número atómico": 24, "masa atómica": 51.996, "grupo": 6, "periodo": 4},
    "Mn": {"nombre": "Manganeso", "número atómico": 25, "masa atómica": 54.938, "grupo": 7, "periodo": 4},
    "Fe": {"nombre": "Hierro", "número atómico": 26, "masa atómica": 55.845, "grupo": 8, "periodo": 4},
    "Co": {"nombre": "Cobalto", "número atómico": 27, "masa atómica": 58.933, "grupo": 9, "periodo": 4},
    "Ni": {"nombre": "Níquel", "número atómico": 28, "masa atómica": 58.693, "grupo": 10, "periodo": 4},
    "Cu": {"nombre": "Cobre", "número atómico": 29, "masa atómica": 63.546, "grupo": 11, "periodo": 4},
    "Zn": {"nombre": "Zinc", "número atómico": 30, "masa atómica": 65.38, "grupo": 12, "periodo": 4},
    "Ga": {"nombre": "Galio", "número atómico": 31, "masa atómica": 69.723, "grupo": 13, "periodo": 4},
    "Ge": {"nombre": "Germanio", "número atómico": 32, "masa atómica": 72.63, "grupo": 14, "periodo": 4},
    "As": {"nombre": "Arsénico", "número atómico": 33, "masa atómica": 74.922, "grupo": 15, "periodo": 4},
    "Se": {"nombre": "Selenio", "número atómico": 34, "masa atómica": 78.971, "grupo": 16, "periodo": 4},
    "Br": {"nombre": "Bromo", "número atómico": 35, "masa atómica": 79.904, "grupo": 17, "periodo": 4},
    "Kr": {"nombre": "Kriptón", "número atómico": 36, "masa atómica": 83.798, "grupo": 18, "periodo": 4},
    "Rb": {"nombre": "Rubidio", "número atómico": 37, "masa atómica": 85.468, "grupo": 1, "periodo": 5},
    "Sr": {"nombre": "Estroncio", "número atómico": 38, "masa atómica": 87.62, "grupo": 2, "periodo": 5},
    "Y": {"nombre": "Itrio", "número atómico": 39, "masa atómica": 88.906, "grupo": 3, "periodo": 5},
    "Zr": {"nombre": "Circonio", "número atómico": 40, "masa atómica": 91.224, "grupo": 4, "periodo": 5},
    "Nb": {"nombre": "Niobio", "número atómico": 41, "masa atómica": 92.906, "grupo": 5, "periodo": 5},
    "Mo": {"nombre": "Molibdeno", "número atómico": 42, "masa atómica": 95.95, "grupo": 6, "periodo": 5},
    "Tc": {"nombre": "Tecnecio", "número atómico": 43, "masa atómica": 98.0, "grupo": 7, "periodo": 5},
    "Ru": {"nombre": "Rutenio", "número atómico": 44, "masa atómica": 101.07, "grupo": 8, "periodo": 5},
    "Rh": {"nombre": "Rodio", "número atómico": 45, "masa atómica": 102.91, "grupo": 9, "periodo": 5},
    "Pd": {"nombre": "Paladio", "número atómico": 46, "masa atómica": 106.42, "grupo": 10, "periodo": 5},
    "Ag": {"nombre": "Plata", "número atómico": 47, "masa atómica": 107.87, "grupo": 11, "periodo": 5},
    "Cd": {"nombre": "Cadmio", "número atómico": 48, "masa atómica": 112.41, "grupo": 12, "periodo": 5},
    "In": {"nombre": "Indio", "número atómico": 49, "masa atómica": 114.82, "grupo": 13, "periodo": 5},
    "Sn": {"nombre": "Estaño", "número atómico": 50, "masa atómica": 118.71, "grupo": 14, "periodo": 5},
    "Sb": {"nombre": "Antimonio", "número atómico": 51, "masa atómica": 121.76, "grupo": 15, "periodo": 5},
    "Te": {"nombre": "Telurio", "número atómico": 52, "masa atómica": 127.6, "grupo": 16, "periodo": 5},
    "I": {"nombre": "Yodo", "número atómico": 53, "masa atómica": 126.9, "grupo": 17, "periodo": 5},
    "Xe": {"nombre": "Xenón", "número atómico": 54, "masa atómica": 131.29, "grupo": 18, "periodo": 5},
    "Cs": {"nombre": "Cesio", "número atómico": 55, "masa atómica": 132.91, "grupo": 1, "periodo": 6},
    "Ba": {"nombre": "Bario", "número atómico": 56, "masa atómica": 137.33, "grupo": 2, "periodo": 6},
    "La": {"nombre": "Lantano", "número atómico": 57, "masa atómica": 138.91, "grupo": 3, "periodo": 6},
    "Ce": {"nombre": "Cerio", "número atómico": 58, "masa atómica": 140.12, "grupo": None, "periodo": 6},
    "Pr": {"nombre": "Praseodimio", "número atómico": 59, "masa atómica": 140.91, "grupo": None, "periodo": 6},
    "Nd": {"nombre": "Neodimio", "número atómico": 60, "masa atómica": 144.24, "grupo": None, "periodo": 6},
    "Pm": {"nombre": "Prometio", "número atómico": 61, "masa atómica": 145.0, "grupo": None, "periodo": 6},
    "Sm": {"nombre": "Samario", "número atómico": 62, "masa atómica": 150.36, "grupo": None, "periodo": 6},
    "Eu": {"nombre": "Europio", "número atómico": 63, "masa atómica": 151.96, "grupo": None, "periodo": 6},
    "Gd": {"nombre": "Gadolinio", "número atómico": 64, "masa atómica": 157.25, "grupo": None, "periodo": 6},
    "Tb": {"nombre": "Terbio", "número atómico": 65, "masa atómica": 158.93, "grupo": None, "periodo": 6},
    "Dy": {"nombre": "Disprosio", "número atómico": 66, "masa atómica": 162.5, "grupo": None, "periodo": 6},
    "Ho": {"nombre": "Holmio", "número atómico": 67, "masa atómica": 164.93, "grupo": None, "periodo": 6},
    "Er": {"nombre": "Erbio", "número atómico": 68, "masa atómica": 167.26, "grupo": None, "periodo": 6},
    "Tm": {"nombre": "Tulio", "número atómico": 69, "masa atómica": 168.93, "grupo": None, "periodo": 6},
    "Yb": {"nombre": "Iterbio", "número atómico": 70, "masa atómica": 173.05, "grupo": None, "periodo": 6},
    "Lu": {"nombre": "Lutecio", "número atómico": 71, "masa atómica": 174.97, "grupo": 3, "periodo": 6},
    "Hf": {"nombre": "Hafnio", "número atómico": 72, "masa atómica": 178.49, "grupo": 4, "periodo": 6},
    "Ta": {"nombre": "Tantalio", "número atómico": 73, "masa atómica": 180.95, "grupo": 5, "periodo": 6},
    "W": {"nombre": "Wolframio", "número atómico": 74, "masa atómica": 183.84, "grupo": 6, "periodo": 6},
    "Re": {"nombre": "Renio", "número atómico": 75, "masa atómica": 186.21, "grupo": 7, "periodo": 6},
    "Os": {"nombre": "Osmio", "número atómico": 76, "masa atómica": 190.23, "grupo": 8, "periodo": 6},
    "Ir": {"nombre": "Iridio", "número atómico": 77, "masa atómica": 192.22, "grupo": 9, "periodo": 6},
    "Pt": {"nombre": "Platino", "número atómico": 78, "masa atómica": 195.08, "grupo": 10, "periodo": 6},
    "Au": {"nombre": "Oro", "número atómico": 79, "masa atómica": 196.97, "grupo": 11, "periodo": 6},
    "Hg": {"nombre": "Mercurio", "número atómico": 80, "masa atómica": 200.59, "grupo": 12, "periodo": 6},
    "Tl": {"nombre": "Talio", "número atómico": 81, "masa atómica": 204.38, "grupo": 13, "periodo": 6},
    "Pb": {"nombre": "Plomo", "número atómico": 82, "masa atómica": 207.2, "grupo": 14, "periodo": 6},
    "Bi": {"nombre": "Bismuto", "número atómico": 83, "masa atómica": 208.98, "grupo": 15, "periodo": 6},
    "Po": {"nombre": "Polonio", "número atómico": 84, "masa atómica": 209.0, "grupo": 16, "periodo": 6},
    "At": {"nombre": "Astato", "número atómico": 85, "masa atómica": 210.0, "grupo": 17, "periodo": 6},
    "Rn": {"nombre": "Radón", "número atómico": 86, "masa atómica": 222.0, "grupo": 18, "periodo": 6},
    "Fr": {"nombre": "Francio", "número atómico": 87, "masa atómica": 223.0, "grupo": 1, "periodo": 7},
    "Ra": {"nombre": "Radio", "número atómico": 88, "masa atómica": 226.0, "grupo": 2, "periodo": 7},
    "Ac": {"nombre": "Actinio", "número atómico": 89, "masa atómica": 227.0, "grupo": 3, "periodo": 7},
    "Th": {"nombre": "Torio", "número atómico": 90, "masa atómica": 232.04, "grupo": None, "periodo": 7},
    "Pa": {"nombre": "Protactinio", "número atómico": 91, "masa atómica": 231.04, "grupo": None, "periodo": 7},
    "U": {"nombre": "Uranio", "número atómico": 92, "masa atómica": 238.03, "grupo": None, "periodo": 7},
    "Np": {"nombre": "Neptunio", "número atómico": 93, "masa atómica": 237.0, "grupo": None, "periodo": 7},
    "Pu": {"nombre": "Plutonio", "número atómico": 94, "masa atómica": 244.0, "grupo": None, "periodo": 7},
    "Am": {"nombre": "Americio", "número atómico": 95, "masa atómica": 243.0, "grupo": None, "periodo": 7},
    "Cm": {"nombre": "Curio", "número atómico": 96, "masa atómica": 247.0, "grupo": None, "periodo": 7},
    "Bk": {"nombre": "Berkelio", "número atómico": 97, "masa atómica": 247.0, "grupo": None, "periodo": 7},
    "Cf": {"nombre": "Californio", "número atómico": 98, "masa atómica": 251.0, "grupo": None, "periodo": 7},
    "Es": {"nombre": "Einsteinio", "número atómico": 99, "masa atómica": 252.0, "grupo": None, "periodo": 7},
    "Fm": {"nombre": "Fermio", "número atómico": 100, "masa atómica": 257.0, "grupo": None, "periodo": 7},
    "Md": {"nombre": "Mendelevio", "número atómico": 101, "masa atómica": 258.0, "grupo": None, "periodo": 7},
    "No": {"nombre": "Nobelio", "número atómico": 102, "masa atómica": 259.0, "grupo": None, "periodo": 7},
    "Lr": {"nombre": "Lawrencio", "número atómico": 103, "masa atómica": 262.0, "grupo": 3, "periodo": 7},
    "Rf": {"nombre": "Rutherfordio", "número atómico": 104, "masa atómica": 267.0, "grupo": 4, "periodo": 7},
    "Db": {"nombre": "Dubnio", "número atómico": 105, "masa atómica": 270.0, "grupo": 5, "periodo": 7},
    "Sg": {"nombre": "Seaborgio", "número atómico": 106, "masa atómica": 271.0, "grupo": 6, "periodo": 7},
    "Bh": {"nombre": "Bohrio", "número atómico": 107, "masa atómica": 270.0, "grupo": 7, "periodo": 7},
    "Hs": {"nombre": "Hassio", "número atómico": 108, "masa atómica": 277.0, "grupo": 8, "periodo": 7},
    "Mt": {"nombre": "Meitnerio", "número atómico": 109, "masa atómica": 278.0, "grupo": 9, "periodo": 7},
    "Ds": {"nombre": "Darmstatio", "número atómico": 110, "masa atómica": 281.0, "grupo": 10, "periodo": 7},
    "Rg": {"nombre": "Roentgenio", "número atómico": 111, "masa atómica": 282.0, "grupo": 11, "periodo": 7},
    "Cn": {"nombre": "Copernicio", "número atómico": 112, "masa atómica": 285.0, "grupo": 12, "periodo": 7},
    "Nh": {"nombre": "Nihonio", "número atómico": 113, "masa atómica": 286.0, "grupo": 13, "periodo": 7},
    "Fl": {"nombre": "Flerovio", "número atómico": 114, "masa atómica": 289.0, "grupo": 14, "periodo": 7},
    "Mc": {"nombre": "Moscovio", "número atómico": 115, "masa atómica": 290.0, "grupo": 15, "periodo": 7},
    "Lv": {"nombre": "Livermorio", "número atómico": 116, "masa atómica": 293.0, "grupo": 16, "periodo": 7},
    "Ts": {"nombre": "Tenesino", "número atómico": 117, "masa atómica": 294.0, "grupo": 17, "periodo": 7},
    "Og": {"nombre": "Oganesón", "número atómico": 118, "masa atómica": 294.0, "grupo": 18, "periodo": 7},
}

def buscar_elemento():
    print("Consulta de la Tabla Periódica")
    simbolo = input("Introduce el símbolo del elemento (ej. H, O, Na): ").capitalize()

    if simbolo in tabla_periodica:
        elemento = tabla_periodica[simbolo]
        print("\nInformación del elemento:")
        print(f"Nombre: {elemento['nombre']}")
        print(f"Número atómico: {elemento['número atómico']}")
        print(f"Masa atómica: {elemento['masa atómica']}")
        print(f"Grupo: {elemento['grupo']}")
        print(f"Período: {elemento['periodo']}")
    else:
        print("Elemento no encontrado.")

buscar_elemento()
# Out:
# Consulta de la Tabla Periódica
# Introduce el símbolo del elemento (ej. H, O, Na):  fe
# Información del elemento:
# Nombre: Hierro
# Número atómico: 26
# Masa atómica: 55.845
# Grupo: 8
# Período: 4
